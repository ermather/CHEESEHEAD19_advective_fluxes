# %%
# !pip install cdflib
# Out:
# ...
#                                               0.0/72.6 kB ? eta -:--:--
#      ---------------------------------------- 72.6/72.6 kB 3.9 MB/s eta 0:00:00
# ...

# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import cdflib

#os.environ["CDF_LIB"] = library_directory

# import os
# os.environ["CDF_LIB"] = "C:\users\emily\miniconda3\lib\site-packages\spacepy\pycdf"
# #'C:\\Users\\emily\\Documents\\Grad_School\\Research\\CHAS\\Test_code'
# #os.environ["CDF_LIB"] = "/home/chuanjiang/Projects/learnable_triangulation/h36m-fetch-master/h36m-fetch-master/cdf37_1-dist/lib"
# from spacepy import pycdf

# %%
#filepath = '../Misc_data/20190711b.c1.nc'
filepath = '../Misc_data/UWKA/aircraft.UWyo_King_Air.20190709_140910_141216.CRL.cdf'
ds = nc.Dataset(filepath)

# %%
#cdf_file = cdflib.CDF('../Misc_data/UWKA/aircraft.UWyo_King_Air.20190709_140910_141216.CRL.cdf')

# %%
var = ds['T'][:]

# %%
# plt.plot(var)

# %%
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     global_att:  This file is generated with our Compact Raman lidar measurements during CHEESEHEAD.
#     global_att1:  The data for each flight is mapped to the same height bin for the entire flight.
#     global_att2: For Question about this product, contact Zhien Wang,
#     global_att3:  University of Colorado, Boulder at Zhien.wang@colorado.edu
#     dimensions(sizes): Charlength(24), layers(140), Time(311)
#     variables(dimensions): |S1 ProductionDateTime(Charlength), int16 VersionID(), float32 Lon(Time), float32 Lat(Time), float32 Alt(Time), float32 T_KA(Time), float32 WVMR_KA(Time), float32 H(layers), float32 time(Time), float32 LSR(Time, layers), float32 WVMR(Time, layers), float32 T(Time, layers)
#     groups:
